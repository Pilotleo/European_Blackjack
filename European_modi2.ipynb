# %% [markdown]
# <a href="https://colab.research.google.com/github/Pilotleo/European_Blackjack/blob/main/European_modi2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
from pandas.core.frame import DataFrame 
from datetime import datetime
import numpy as np
class cards:
  def __init__(self,point,name,color,weighted):
    self.point =point 
    self.name =name
    self.color=color
    self.weighted = weighted
#simulation['p1'].apply(lambda row: play_card(row))

# %%
#土炮新增六副牌，命名規則：花色_組_牌面 spade heart diamond club
S_1_1=cards(1,'A','spade',-1)
S_1_1.ACE='1'
S_1_2=cards(2,'2','spade',1)
S_1_3=cards(3,'3','spade',1)
S_1_4=cards(4,'4','spade',1)
S_1_5=cards(5,'5','spade',1)
S_1_6=cards(6,'6','spade',1)
S_1_7=cards(7,'7','spade',0)
S_1_8=cards(8,'8','spade',0)
S_1_9=cards(9,'9','spade',0)
S_1_10=cards(10,'10','spade',-1)
S_1_J=cards(10,'J','spade',-1)
S_1_Q=cards(10,'Q','spade',-1)
S_1_K=cards(10,'K','spade',-1)
H_1_1=cards(1,'A','Heart',-1)
H_1_1.ACE='1'
H_1_2=cards(2,'2','Heart',1)
H_1_3=cards(3,'3','Heart',1)
H_1_4=cards(4,'4','Heart',1)
H_1_5=cards(5,'5','Heart',1)
H_1_6=cards(6,'6','Heart',1)
H_1_7=cards(7,'7','Heart',0)
H_1_8=cards(8,'8','Heart',0)
H_1_9=cards(9,'9','Heart',0)
H_1_10=cards(10,'10','Heart',-1)
H_1_J=cards(10,'J','Heart',-1)
H_1_Q=cards(10,'Q','Heart',-1)
H_1_K=cards(10,'K','Heart',-1)
D_1_1=cards(1,'A','Diamond',-1)
D_1_1.ACE='1'
D_1_2=cards(2,'2','Diamond',1)
D_1_3=cards(3,'3','Diamond',1)
D_1_4=cards(4,'4','Diamond',1)
D_1_5=cards(5,'5','Diamond',1)
D_1_6=cards(6,'6','Diamond',1)
D_1_7=cards(7,'7','Diamond',0)
D_1_8=cards(8,'8','Diamond',0)
D_1_9=cards(9,'9','Diamond',0)
D_1_10=cards(10,'10','Diamond',-1)
D_1_J=cards(10,'J','Diamond',-1)
D_1_Q=cards(10,'Q','Diamond',-1)
D_1_K=cards(10,'K','Diamond',-1)
C_1_1=cards(1,'A','Club',-1)
C_1_1.ACE='1'
C_1_2=cards(2,'2','Club',1)
C_1_3=cards(3,'3','Club',1)
C_1_4=cards(4,'4','Club',1)
C_1_5=cards(5,'5','Club',1)
C_1_6=cards(6,'6','Club',1)
C_1_7=cards(7,'7','Club',0)
C_1_8=cards(8,'8','Club',0)
C_1_9=cards(9,'9','Club',0)
C_1_10=cards(10,'10','Club',-1)
C_1_J=cards(10,'J','Club',-1)
C_1_Q=cards(10,'Q','Club',-1)
C_1_K=cards(10,'K','Club',-1)
desk1=[S_1_1,S_1_2,S_1_3,S_1_4,S_1_5,S_1_6,S_1_7,S_1_8,S_1_9,S_1_10,S_1_J,S_1_Q,S_1_K,
       H_1_1,H_1_2,H_1_3,H_1_4,H_1_5,H_1_6,H_1_7,H_1_8,H_1_9,H_1_10,H_1_J,H_1_Q,H_1_K,
       D_1_1,D_1_2,D_1_3,D_1_4,D_1_5,D_1_6,D_1_7,D_1_8,D_1_9,D_1_10,D_1_J,D_1_Q,D_1_K,
       C_1_1,C_1_2,C_1_3,C_1_4,C_1_5,C_1_6,C_1_7,C_1_8,C_1_9,C_1_10,C_1_J,C_1_Q,C_1_K
       ]
#第二副
S_2_1=cards(1,'A','spade',-1)
S_2_1.ACE='1'
S_2_2=cards(2,'2','spade',1)
S_2_3=cards(3,'3','spade',1)
S_2_4=cards(4,'4','spade',1)
S_2_5=cards(5,'5','spade',1)
S_2_6=cards(6,'6','spade',1)
S_2_7=cards(7,'7','spade',0)
S_2_8=cards(8,'8','spade',0)
S_2_9=cards(9,'9','spade',0)
S_2_10=cards(10,'10','spade',-1)
S_2_J=cards(10,'J','spade',-1)
S_2_Q=cards(10,'Q','spade',-1)
S_2_K=cards(10,'K','spade',-1)
H_2_1=cards(1,'A','Heart',-1)
H_2_1.ACE='1'
H_2_2=cards(2,'2','Heart',1)
H_2_3=cards(3,'3','Heart',1)
H_2_4=cards(4,'4','Heart',1)
H_2_5=cards(5,'5','Heart',1)
H_2_6=cards(6,'6','Heart',1)
H_2_7=cards(7,'7','Heart',0)
H_2_8=cards(8,'8','Heart',0)
H_2_9=cards(9,'9','Heart',0)
H_2_10=cards(10,'10','Heart',-1)
H_2_J=cards(10,'J','Heart',-1)
H_2_Q=cards(10,'Q','Heart',-1)
H_2_K=cards(10,'K','Heart',-1)
D_2_1=cards(1,'A','Diamond',-1)
D_2_1.ACE='1'
D_2_2=cards(2,'2','Diamond',1)
D_2_3=cards(3,'3','Diamond',1)
D_2_4=cards(4,'4','Diamond',1)
D_2_5=cards(5,'5','Diamond',1)
D_2_6=cards(6,'6','Diamond',1)
D_2_7=cards(7,'7','Diamond',0)
D_2_8=cards(8,'8','Diamond',0)
D_2_9=cards(9,'9','Diamond',0)
D_2_10=cards(10,'10','Diamond',-1)
D_2_J=cards(10,'J','Diamond',-1)
D_2_Q=cards(10,'Q','Diamond',-1)
D_2_K=cards(10,'K','Diamond',-1)
C_2_1=cards(1,'A','Club',-1)
C_2_1.ACE='1'
C_2_2=cards(2,'2','Club',1)
C_2_3=cards(3,'3','Club',1)
C_2_4=cards(4,'4','Club',1)
C_2_5=cards(5,'5','Club',1)
C_2_6=cards(6,'6','Club',1)
C_2_7=cards(7,'7','Club',0)
C_2_8=cards(8,'8','Club',0)
C_2_9=cards(9,'9','Club',0)
C_2_10=cards(10,'10','Club',-1)
C_2_J=cards(10,'J','Club',-1)
C_2_Q=cards(10,'Q','Club',-1)
C_2_K=cards(10,'K','Club',-1)
desk2=[S_2_1,S_2_2,S_2_3,S_2_4,S_2_5,S_2_6,S_2_7,S_2_8,S_2_9,S_2_10,S_2_J,S_2_Q,S_2_K,
  H_2_1,H_2_2,H_2_3,H_2_4,H_2_5,H_2_6,H_2_7,H_2_8,H_2_9,H_2_10,H_2_J,H_2_Q,H_2_K,
  D_2_1,D_2_2,D_2_3,D_2_4,D_2_5,D_2_6,D_2_7,D_2_8,D_2_9,D_2_10,D_2_J,D_2_Q,D_2_K,
  C_2_1,C_2_2,C_2_3,C_2_4,C_2_5,C_2_6,C_2_7,C_2_8,C_2_9,C_2_10,C_2_J,C_2_Q,C_1_K
  ]


#第三副
S_3_1=cards(1,'A','spade',-1)
S_3_1.ACE='1'
S_3_2=cards(2,'2','spade',1)
S_3_3=cards(3,'3','spade',1)
S_3_4=cards(4,'4','spade',1)
S_3_5=cards(5,'5','spade',1)
S_3_6=cards(6,'6','spade',1)
S_3_7=cards(7,'7','spade',0)
S_3_8=cards(8,'8','spade',0)
S_3_9=cards(9,'9','spade',0)
S_3_10=cards(10,'10','spade',-1)
S_3_J=cards(10,'J','spade',-1)
S_3_Q=cards(10,'Q','spade',-1)
S_3_K=cards(10,'K','spade',-1)
H_3_1=cards(1,'A','Heart',-1)
H_3_1.ACE='1'
H_3_2=cards(2,'2','Heart',1)
H_3_3=cards(3,'3','Heart',1)
H_3_4=cards(4,'4','Heart',1)
H_3_5=cards(5,'5','Heart',1)
H_3_6=cards(6,'6','Heart',1)
H_3_7=cards(7,'7','Heart',0)
H_3_8=cards(8,'8','Heart',0)
H_3_9=cards(9,'9','Heart',0)
H_3_10=cards(10,'10','Heart',-1)
H_3_J=cards(10,'J','Heart',-1)
H_3_Q=cards(10,'Q','Heart',-1)
H_3_K=cards(10,'K','Heart',-1)
D_3_1=cards(1,'A','Diamond',-1)
D_3_1.ACE='1'
D_3_2=cards(2,'2','Diamond',1)
D_3_3=cards(3,'3','Diamond',1)
D_3_4=cards(4,'4','Diamond',1)
D_3_5=cards(5,'5','Diamond',1)
D_3_6=cards(6,'6','Diamond',1)
D_3_7=cards(7,'7','Diamond',0)
D_3_8=cards(8,'8','Diamond',0)
D_3_9=cards(9,'9','Diamond',0)
D_3_10=cards(10,'10','Diamond',-1)
D_3_J=cards(10,'J','Diamond',-1)
D_3_Q=cards(10,'Q','Diamond',-1)
D_3_K=cards(10,'K','Diamond',-1)
C_3_1=cards(1,'A','Club',-1)
C_3_1.ACE='1'
C_3_2=cards(2,'2','Club',1)
C_3_3=cards(3,'3','Club',1)
C_3_4=cards(4,'4','Club',1)
C_3_5=cards(5,'5','Club',1)
C_3_6=cards(6,'6','Club',1)
C_3_7=cards(7,'7','Club',0)
C_3_8=cards(8,'8','Club',0)
C_3_9=cards(9,'9','Club',0)
C_3_10=cards(10,'10','Club',-1)
C_3_J=cards(10,'J','Club',-1)
C_3_Q=cards(10,'Q','Club',-1)
C_3_K=cards(10,'K','Club',-1)
desk3=[S_3_1,S_3_2,S_3_3,S_3_4,S_3_5,S_3_6,S_3_7,S_3_8,S_3_9,S_3_10,S_3_J,S_3_Q,S_3_K,
       H_3_1,H_3_2,H_3_3,H_3_4,H_3_5,H_3_6,H_3_7,H_3_8,H_3_9,H_3_10,H_3_J,H_3_Q,H_3_K,
       D_3_1,D_3_2,D_3_3,D_3_4,D_3_5,D_3_6,D_3_7,D_3_8,D_3_9,D_3_10,D_3_J,D_3_Q,D_3_K,
       C_3_1,C_3_2,C_3_3,C_3_4,C_3_5,C_3_6,C_3_7,C_3_8,C_3_9,C_3_10,C_3_J,C_3_Q,C_1_K
       ]
#第四副
S_4_1=cards(1,'A','spade',-1)
S_4_1.ACE='1'
S_4_2=cards(2,'2','spade',1)
S_4_3=cards(3,'3','spade',1)
S_4_4=cards(4,'4','spade',1)
S_4_5=cards(5,'5','spade',1)
S_4_6=cards(6,'6','spade',1)
S_4_7=cards(7,'7','spade',0)
S_4_8=cards(8,'8','spade',0)
S_4_9=cards(9,'9','spade',0)
S_4_10=cards(10,'10','spade',-1)
S_4_J=cards(10,'J','spade',-1)
S_4_Q=cards(10,'Q','spade',-1)
S_4_K=cards(10,'K','spade',-1)
H_4_1=cards(1,'A','Heart',-1)
H_4_1.ACE='1'
H_4_2=cards(2,'2','Heart',1)
H_4_3=cards(3,'3','Heart',1)
H_4_4=cards(4,'4','Heart',1)
H_4_5=cards(5,'5','Heart',1)
H_4_6=cards(6,'6','Heart',1)
H_4_7=cards(7,'7','Heart',0)
H_4_8=cards(8,'8','Heart',0)
H_4_9=cards(9,'9','Heart',0)
H_4_10=cards(10,'10','Heart',-1)
H_4_J=cards(10,'J','Heart',-1)
H_4_Q=cards(10,'Q','Heart',-1)
H_4_K=cards(10,'K','Heart',-1)
D_4_1=cards(1,'A','Diamond',-1)
D_4_1.ACE='1'
D_4_2=cards(2,'2','Diamond',1)
D_4_3=cards(3,'3','Diamond',1)
D_4_4=cards(4,'4','Diamond',1)
D_4_5=cards(5,'5','Diamond',1)
D_4_6=cards(6,'6','Diamond',1)
D_4_7=cards(7,'7','Diamond',0)
D_4_8=cards(8,'8','Diamond',0)
D_4_9=cards(9,'9','Diamond',0)
D_4_10=cards(10,'10','Diamond',-1)
D_4_J=cards(10,'J','Diamond',-1)
D_4_Q=cards(10,'Q','Diamond',-1)
D_4_K=cards(10,'K','Diamond',-1)
C_4_1=cards(1,'A','Club',-1)
C_4_1.ACE='1'
C_4_2=cards(2,'2','Club',1)
C_4_3=cards(3,'3','Club',1)
C_4_4=cards(4,'4','Club',1)
C_4_5=cards(5,'5','Club',1)
C_4_6=cards(6,'6','Club',1)
C_4_7=cards(7,'7','Club',0)
C_4_8=cards(8,'8','Club',0)
C_4_9=cards(9,'9','Club',0)
C_4_10=cards(10,'10','Club',-1)
C_4_J=cards(10,'J','Club',-1)
C_4_Q=cards(10,'Q','Club',-1)
C_4_K=cards(10,'K','Club',-1)
desk4=[S_4_1,S_4_2,S_4_3,S_4_4,S_4_5,S_4_6,S_4_7,S_4_8,S_4_9,S_4_10,S_4_J,S_4_Q,S_4_K,
       H_4_1,H_4_2,H_4_3,H_4_4,H_4_5,H_4_6,H_4_7,H_4_8,H_4_9,H_4_10,H_4_J,H_4_Q,H_4_K,
       D_4_1,D_4_2,D_4_3,D_4_4,D_4_5,D_4_6,D_4_7,D_4_8,D_4_9,D_4_10,D_4_J,D_4_Q,D_4_K,
       C_4_1,C_4_2,C_4_3,C_4_4,C_4_5,C_4_6,C_4_7,C_4_8,C_4_9,C_4_10,C_4_J,C_4_Q,C_1_K
       ]
#第五副
S_5_1=cards(1,'A','spade',-1)
S_5_1.ACE='1'
S_5_2=cards(2,'2','spade',1)
S_5_3=cards(3,'3','spade',1)
S_5_4=cards(4,'4','spade',1)
S_5_5=cards(5,'5','spade',1)
S_5_6=cards(6,'6','spade',1)
S_5_7=cards(7,'7','spade',0)
S_5_8=cards(8,'8','spade',0)
S_5_9=cards(9,'9','spade',0)
S_5_10=cards(10,'10','spade',-1)
S_5_J=cards(10,'J','spade',-1)
S_5_Q=cards(10,'Q','spade',-1)
S_5_K=cards(10,'K','spade',-1)
H_5_1=cards(1,'A','Heart',-1)
H_5_1.ACE='1'
H_5_2=cards(2,'2','Heart',1)
H_5_3=cards(3,'3','Heart',1)
H_5_4=cards(4,'4','Heart',1)
H_5_5=cards(5,'5','Heart',1)
H_5_6=cards(6,'6','Heart',1)
H_5_7=cards(7,'7','Heart',0)
H_5_8=cards(8,'8','Heart',0)
H_5_9=cards(9,'9','Heart',0)
H_5_10=cards(10,'10','Heart',-1)
H_5_J=cards(10,'J','Heart',-1)
H_5_Q=cards(10,'Q','Heart',-1)
H_5_K=cards(10,'K','Heart',-1)
D_5_1=cards(1,'A','Diamond',-1)
D_5_1.ACE='1'
D_5_2=cards(2,'2','Diamond',1)
D_5_3=cards(3,'3','Diamond',1)
D_5_4=cards(4,'4','Diamond',1)
D_5_5=cards(5,'5','Diamond',1)
D_5_6=cards(6,'6','Diamond',1)
D_5_7=cards(7,'7','Diamond',0)
D_5_8=cards(8,'8','Diamond',0)
D_5_9=cards(9,'9','Diamond',0)
D_5_10=cards(10,'10','Diamond',-1)
D_5_J=cards(10,'J','Diamond',-1)
D_5_Q=cards(10,'Q','Diamond',-1)
D_5_K=cards(10,'K','Diamond',-1)
C_5_1=cards(1,'A','Club',-1)
C_5_1.ACE='1'
C_5_2=cards(2,'2','Club',1)
C_5_3=cards(3,'3','Club',1)
C_5_4=cards(4,'4','Club',1)
C_5_5=cards(5,'5','Club',1)
C_5_6=cards(6,'6','Club',1)
C_5_7=cards(7,'7','Club',0)
C_5_8=cards(8,'8','Club',0)
C_5_9=cards(9,'9','Club',0)
C_5_10=cards(10,'10','Club',-1)
C_5_J=cards(10,'J','Club',-1)
C_5_Q=cards(10,'Q','Club',-1)
C_5_K=cards(10,'K','Club',-1)
desk5=[S_5_1,S_5_2,S_5_3,S_5_4,S_5_5,S_5_6,S_5_7,S_5_8,S_5_9,S_5_10,S_5_J,S_5_Q,S_5_K,
  H_5_1,H_5_2,H_5_3,H_5_4,H_5_5,H_5_6,H_5_7,H_5_8,H_5_9,H_5_10,H_5_J,H_5_Q,H_5_K,
  D_5_1,D_5_2,D_5_3,D_5_4,D_5_5,D_5_6,D_5_7,D_5_8,D_5_9,D_5_10,D_5_J,D_5_Q,D_5_K,
  C_5_1,C_5_2,C_5_3,C_5_4,C_5_5,C_5_6,C_5_7,C_5_8,C_5_9,C_5_10,C_5_J,C_5_Q,C_1_K
  ]
#第六副
S_6_1=cards(1,'A','spade',-1)
S_6_1.ACE='1'
S_6_2=cards(2,'2','spade',1)
S_6_3=cards(3,'3','spade',1)
S_6_4=cards(4,'4','spade',1)
S_6_5=cards(5,'5','spade',1)
S_6_6=cards(6,'6','spade',1)
S_6_7=cards(7,'7','spade',0)
S_6_8=cards(8,'8','spade',0)
S_6_9=cards(9,'9','spade',0)
S_6_10=cards(10,'10','spade',-1)
S_6_J=cards(10,'J','spade',-1)
S_6_Q=cards(10,'Q','spade',-1)
S_6_K=cards(10,'K','spade',-1)
H_6_1=cards(1,'A','Heart',-1)
H_6_1.ACE='1'
H_6_2=cards(2,'2','Heart',1)
H_6_3=cards(3,'3','Heart',1)
H_6_4=cards(4,'4','Heart',1)
H_6_5=cards(5,'5','Heart',1)
H_6_6=cards(6,'6','Heart',1)
H_6_7=cards(7,'7','Heart',0)
H_6_8=cards(8,'8','Heart',0)
H_6_9=cards(9,'9','Heart',0)
H_6_10=cards(10,'10','Heart',-1)
H_6_J=cards(10,'J','Heart',-1)
H_6_Q=cards(10,'Q','Heart',-1)
H_6_K=cards(10,'K','Heart',-1)
D_6_1=cards(1,'A','Diamond',-1)
D_6_1.ACE='1'
D_6_2=cards(2,'2','Diamond',1)
D_6_3=cards(3,'3','Diamond',1)
D_6_4=cards(4,'4','Diamond',1)
D_6_5=cards(5,'5','Diamond',1)
D_6_6=cards(6,'6','Diamond',1)
D_6_7=cards(7,'7','Diamond',0)
D_6_8=cards(8,'8','Diamond',0)
D_6_9=cards(9,'9','Diamond',0)
D_6_10=cards(10,'10','Diamond',-1)
D_6_J=cards(10,'J','Diamond',-1)
D_6_Q=cards(10,'Q','Diamond',-1)
D_6_K=cards(10,'K','Diamond',-1)
C_6_1=cards(1,'A','Club',-1)
C_6_1.ACE='1'
C_6_2=cards(2,'2','Club',1)
C_6_3=cards(3,'3','Club',1)
C_6_4=cards(4,'4','Club',1)
C_6_5=cards(5,'5','Club',1)
C_6_6=cards(6,'6','Club',1)
C_6_7=cards(7,'7','Club',0)
C_6_8=cards(8,'8','Club',0)
C_6_9=cards(9,'9','Club',0)
C_6_10=cards(10,'10','Club',-1)
C_6_J=cards(10,'J','Club',-1)
C_6_Q=cards(10,'Q','Club',-1)
C_6_K=cards(10,'K','Club',-1)
desk6=[S_6_1,S_6_2,S_6_3,S_6_4,S_6_5,S_6_6,S_6_7,S_6_8,S_6_9,S_6_10,S_6_J,S_6_Q,S_6_K,
        H_6_1,H_6_2,H_6_3,H_6_4,H_6_5,H_6_6,H_6_7,H_6_8,H_6_9,H_6_10,H_6_J,H_6_Q,H_6_K,
        D_6_1,D_6_2,D_6_3,D_6_4,D_6_5,D_6_6,D_6_7,D_6_8,D_6_9,D_6_10,D_6_J,D_6_Q,D_6_K,
        C_6_1,C_6_2,C_6_3,C_6_4,C_6_5,C_6_6,C_6_7,C_6_8,C_6_9,C_6_10,C_6_J,C_6_Q,C_1_K
  ]

# %%
def shuffle(desk,seed):
    desk1 = desk.copy()
    np.random.seed(seed) 
    np.random.shuffle(desk1)
    return desk1

def distribution(row,pos1,pos2):
    return [row[pos1],row[pos2]]

# %%
def first_bet(true_num):
    '''
    用來計算一開始下注
    paras:
        p_card 傳入真數
    return
        bet    下注     type:int
    history:2022/10/9 done
    '''
    if true_num >=6:
        bet = 30
    elif true_num ==5:
        bet = 25
    elif true_num ==4:
        bet = 20
    elif true_num ==3:
        bet = 15
    elif true_num ==2:
        bet = 10
    elif true_num ==1:
        bet = 5
    else:
        bet = 1
    return bet

# %%
def game_start(true_num,weight):
    
    '''###game_start 這個Function主要用來遊戲開局，初始化每個人的牌庫狀態，並將狀態寫入simulation中
    Paras:
        true_num:該手結束的真數     type:int    ex:3  
        weight:該手結束的權重      type:int    ex:15
    Returns:
        None
    
    '''

    bet= first_bet(true_num)
    d_sts={'weight':0,'bet':bet,'card_big':0,'card_small':0,'card_total':0,'card_ACE':0,'card_point':0,'ACE_Point':0,'BJ':'N',
         'Bust':'N','double_available':'Y','Stand':'N','Split_available':'N','Split_count':0,'Split_ACE':'N','surrender':'N'}

    simulation['p1_sts']=simulation['p1'].apply(lambda row:bf_sts_cal([row][0],bet))
    simulation['p2_sts']=simulation['p2'].apply(lambda row:bf_sts_cal([row][0],bet))
    simulation['p3_sts']=simulation['p3'].apply(lambda row:bf_sts_cal([row][0],bet))

# %%
def card_count(p_card):
    '''
    被呼叫來算點數、大小牌、用掉的牌數、以及有沒有ACE等等
    這裡產出的狀態會放在dataframe裡面，計算包含了BJ、兩張A可拆、一般牌可拆、一般牌可加倍
    paras:
        p_card 傳入要計算的牌組 type:List()，List裡面放card物件
    return
        card_total 總共的牌數 其實都是2
        card_big   總共的大牌
        card_small 總共的小牌
        card_ACE   總共的ACE數
        ACE_Point  依照有沒有ACE動態判斷點數。
    history:2022/10/9 done
    '''
    if p_card[1].point==1 or p_card[0].point==1:
        card_ACE = 1
        ACE_Point=p_card[1].point+p_card[0].point+10
    else:
        card_ACE = 0
        ACE_Point=0
    if p_card[0].weighted ==1:
        card_big = 0
        card_small = 1
    elif p_card[0].weighted == -1:
        card_big = 1
        card_small = 0
    else :
        card_big = 0
        card_small = 0
    if p_card[1].weighted ==1:
        card_big += 0
        card_small += 1
    elif p_card[1].weighted ==-1:
        card_big += 1
        card_small += 0
    else :
        card_big += 0
        card_small += 0    
    card_total=2
    
    return card_total,card_big,card_small,card_ACE,ACE_Point

# %%
def bf_sts_cal(p_card,bet):
    '''
    用來計算一開始的兩張，總共會帶來的狀態，需要呼叫card_count，去算點數、大小牌、用掉的牌數、以及有沒有ACE等等
    這裡產出的狀態會放在dataframe裡面，計算包含了BJ、兩張A可拆、一般牌可拆、一般牌可加倍
    paras:
        p_card 傳入要計算的牌組 type:List()，List裡面放card物件
        bet    起始的注碼       type:int  
    return
        p_sts  該牌組的狀態     type:dict() 
    history:2022/10/9 done
    '''
#     print(p_card)

    if (p_card[0].point+p_card[1].point==11) and (p_card[0].point or p_card[1].point==1):#只有兩張時加起來十一點且有一張為1，就是BJ
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':2,'card_small':0,'card_total':2,'card_ACE':1,'card_point':21,'ACE_Point':21,
                  'BJ':'Y','Bust':'N','double_available':'N','Stand':'N','Split_available':'N','Split_count':0,'Split_ACE':'N'
                  ,'surrender':'N'}
        return p_sts
    elif (p_card[0].point == p_card[1].point) and (p_card[0].point==1 or p_card[1].point==1):#兩張A的拆牌
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':2,'card_small':0,'card_total':2,'card_ACE':2,'card_point':2,'ACE_Point':12,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'Y','Split_count':0,'Split_ACE':'Y'
                  ,'surrender':'N'}
        return p_sts
    elif (p_card[0].point == p_card[1].point) and (p_card[1].point!=1):#兩張其他的拆牌
        card_total,card_big,card_small,card_ACE,ACE_Point=card_count(p_card)
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point*2,'ACE_Point':0,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'Y','Split_count':0,'Split_ACE':'N'
                  ,'surrender':'N'}
        return p_sts
    else:
        card_total,card_big,card_small,card_ACE,ACE_Point=card_count(p_card)
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':0,
                  'BJ':'N','Bust':'N','double_available':'Y','Stand':'N','Split_available':'N','Split_count':0,'Split_ACE':'N'
                  ,'surrender':'N'}
        return p_sts

# %%
def bf_sts_cal_for_dealer(p_card):
    '''
    用來計算莊家一開始的兩張，總共會帶來的狀態，需要呼叫card_count，去算點數、大小牌、用掉的牌數、以及有沒有ACE等等
    這裡產出的狀態會放在dataframe裡面，計算包含了BJ、一般牌
    paras:
        p_card 傳入要計算的牌組 type:List()，List裡面放card物件
        bet    起始的注碼       type:int  
    return
        p_sts  該牌組的狀態     type:dict() 
    history:2022/10/9 done
    '''
#     print(p_card)

    if (p_card[0].point+p_card[1].point==11) and (p_card[0].point==1 or p_card[1].point==1):#只有兩張時加起來十一點且有一張為1，就是BJ
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':0,'card_big':2,'card_small':0,'card_total':2,'card_ACE':1,'card_point':21,'ACE_Point':21,
                  'BJ':'Y','Bust':'N','double_available':'N','Stand':'N','Split_available':'N','Split_count':0,'Split_ACE':'N'
                  ,'surrender':'N'}
        return p_sts
    else:
        card_total,card_big,card_small,card_ACE,ACE_Point=card_count(p_card)
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':0,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':0,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'N','Split_count':0,'Split_ACE':'N'
                  ,'surrender':'N'}
        return p_sts

# %%
def revenue_cal(row):
    total_revenue=row['p1_revenue']+row['p2_revenue']+row['p3_revenue']+row['p1_1_revenue']+row['p1_2_revenue']+row['p2_1_revenue']+row['p2_2_revenue']+row['p3_1_revenue']+row['p3_2_revenue']
    return total_revenue

# %%
def t_weight_cal(row):
#     print(row)
   
    t_weight=row['p1_sts']['weight']+row['p2_sts']['weight']+row['p3_sts']['weight']
    if row['p1_1_sts']!=0:
        t_weight+=row['p1_1_sts']['weight']
    else:
        t_weight+=0
    if row['p1_2_sts']!=0:
        t_weight+=row['p1_2_sts']['weight']
    else:
        t_weight+=0
    if row['p2_1_sts']!=0:
        t_weight+=row['p2_1_sts']['weight']
    else:
        t_weight+=0
    if row['p2_2_sts']!=0:
        t_weight+=row['p2_2_sts']['weight']
    else:
        t_weight+=0
    if row['p3_1_sts']!=0:
        t_weight+=row['p3_1_sts']['weight']
    else:
        t_weight+=0
    if row['p3_2_sts']!=0:
        t_weight+=row['p3_2_sts']['weight']
    else:
        t_weight+=0
    return t_weight

# %%
def t_weight_adjust(t_weight):
    if t_weight>0:
        t_weight_adjust =t_weight-1
    elif t_weight <0:
        t_weight_adjust =t_weight+1
    else:
        t_weight_adjust =t_weight
    return t_weight_adjust

# %%
def play_card(p_sts,p_card,d_card,desk,bet):
    ''' ###play_card，主要打牌的行程，
    Paras:
        p_sts, 自已牌的狀態，決定要hit、Stand還是要分牌、double、爆牌等等
        p_card 自己的牌組，傳進來之後也需要靠他再去繼續往下增加牌
        d_card 莊家的牌，會影響自己的打法
    Returns:
        None.
    '''
    
    if p_card ==0 or p_sts['Bust']=='Y' or p_sts['surrender']=='Y'or p_sts['BJ']=='Y':#合條件就不要再跳進來了
        return 0
#     print(p_sts['Bust'])
#     print(p_sts['BJ'])
#     print(p_sts['ACE_Point'])
#     print(p_sts['card_point'])
#     print(p_sts['surrender'])
#     print(p_sts)
    
    
    while (p_sts['Bust']=='N'and p_sts['BJ']=='N' and (p_sts['ACE_Point']<=21 or p_sts['card_point']<=21)and p_sts['surrender']=='N'):
        card_point=0
        card_ACE=0
        ACE_Point=0
        for i in range(len(p_card)):
            if p_card[i].point==1:
                card_ACE += 1
            else:
                card_ACE += 0
            card_point+=p_card[i].point
        if card_ACE>=1:
            ACE_Point=card_point+10
        else:
            ACE_Point=card_point
        p_sts['card_point']=card_point
        p_sts['card_ACE']=card_ACE
        p_sts['ACE_Point']=ACE_Point
#         if p_card[0].point==p_card[1].point:
#             print('判斷一')
#             if p_sts['card_point']==21 or p_sts['Stand'] =='Y':
#                 p_sts['Stand'] ='Y'
#                 break
#             elif p_sts['card_point']==20:
#                 p_sts['Stand'] ='Y'
#                 break
#             elif p_sts['card_point']==18 and (d_card[0].point==7 or d_card[0].point==1or d_card[0].point==10):
#                 p_sts['Stand'] ='Y'
#                 break  
#             elif (p_sts['card_point']==16 or p_sts['card_point']==14) and d_card[0].point==1:
#                 p_sts= hit(p_card,desk,bet)
#             elif (p_sts['card_point']==16 or p_sts['card_point']==14)  and d_card[0].point==10:
#                 p_sts=surrender(p_sts,p_card,desk,bet)
#             elif p_sts['card_point']==14 and (d_card[0].point==9 or d_card[0].point==8):
#                 p_sts= hit(p_card,desk,bet)
#             elif p_sts['card_point']==12 and (d_card[0].point==7 or d_card[0].point==8 or d_card[0].point==10 or d_card[0].point==1 or d_card[0].point==9):
#                 p_sts= hit(p_card,desk,bet)
#             elif p_sts['card_point']==10 and (d_card[0].point==1 or d_card[0].point==10):
#                 p_sts= hit(p_card,desk,bet)
#             elif p_sts['card_point']==10 :
#                 p_sts=Double(p_sts,p_card,desk,bet,'hit')
#             elif p_sts['card_point']==8:
#                 p_sts= hit(p_card,desk,bet)
#             elif d_card[0].point==8 or d_card[0].point==9 or d_card[0].point==10 or d_card[0].point==1:
#                 p_sts= hit(p_card,desk,bet)
#             else:
#                 print('ACE Play go wrong','p_sts = ',p_sts,'d_card=',d_card[0].point)
# #                 os._exit()
        if p_sts['ACE_Point']>=p_sts['card_point'] and p_sts['card_ACE']>0 : # soft_play
#             print('判斷二')
#           for i in range (len(p_card)):
#             p_sts['card_point']+=p_card[i].point
#           p_sts['ACE_Point']=p_sts['card_point']+10
            if p_sts['BJ'] == 'Y' or p_sts['Stand'] =='Y':
                break
            elif p_sts['ACE_Point']>=19 :
                p_sts['Stand'] ='Y'
                break
            elif p_sts['ACE_Point']==18 and (d_card[0].point>=9 or d_card[0].point==1):
                p_sts= hit(p_sts,p_card,desk,bet)
            elif p_sts['ACE_Point']==18 and (d_card[0].point==3 or d_card[0].point==4 or d_card[0].point==5 or d_card[0].point==6):
                p_sts=Double(p_sts,p_card,desk,bet,'stand')
                break
            elif p_sts['ACE_Point']==18 and (d_card[0].point==8 or d_card[0].point==2 or d_card[0].point==7):
                p_sts['Stand'] ='Y'
                break
            elif p_sts['ACE_Point']<=17 and (d_card[0].point>=7 or d_card[0].point==1):
                p_sts= hit(p_sts,p_card,desk,bet)
            elif p_sts['ACE_Point']<=17 and (d_card[0].point==5 or d_card[0].point==6 ):
                p_sts=Double(p_sts,p_card,desk,bet,'hit')
            elif p_sts['ACE_Point']>=15 and p_sts['ACE_Point']<=17 and (d_card[0].point==4 or d_card[0].point==5 or d_card[0].point==6 ):
                p_sts=Double(p_sts,p_card,desk,bet,'hit')
            elif (p_sts['ACE_Point']==14 or p_sts['ACE_Point']==13) and (d_card[0].point>=4):
                p_sts= hit(p_sts,p_card,desk,bet)
            elif p_sts['ACE_Point']==17 and (d_card[0].point==3):
                p_sts=Double(p_sts,p_card,desk,bet,'hit')
            elif p_sts['ACE_Point']<=16 and (d_card[0].point==3):
                p_sts= hit(p_sts,p_card,desk,bet)
            elif p_sts['ACE_Point']<=17 and (d_card[0].point==2):
                p_sts= hit(p_sts,p_card,desk,bet)
            elif p_sts['Split_count']>0:#分過一次的就直接結束
                break
            else:
                print('Soft Play go wrong','p_sts = ',p_sts,'p_card','d_card=',d_card[0].point)
                for i in range(len(p_card)):
                    print(p_card[i].point)
                break
#                 os._exit()
        else: # Hard_play
#             print('判斷三')
            if p_sts['card_point'] >= 17:
                p_sts['Stand'] ='Y'
                break
            elif p_sts['card_point'] ==16 and (d_card[0].point==9 or d_card[0].point==10):
                p_sts=surrender(p_sts,p_card,desk,bet)
            elif p_sts['card_point'] ==16 and (d_card[0].point==1 or d_card[0].point==8 or d_card[0].point==7):
                p_sts= hit(p_sts,p_card,desk,bet)
            elif p_sts['card_point'] ==16:
                p_sts['Stand'] ='Y'
                break
            elif (p_sts['card_point'] ==15 or p_sts['card_point'] ==14) and (d_card[0].point==10):
                p_sts=surrender(p_sts,p_card,desk,bet)
            elif (p_sts['card_point'] ==15 or p_sts['card_point'] ==14) and (d_card[0].point==1 or d_card[0].point==8 or d_card[0].point==7 or d_card[0].point==9):
                p_sts= hit(p_sts,p_card,desk,bet)
            elif (p_sts['card_point'] ==15 or p_sts['card_point'] ==14):
                p_sts['Stand'] ='Y'
                break
            elif (p_sts['card_point'] ==13 or p_sts['card_point'] ==12)and (d_card[0].point==1 or d_card[0].point==8 or d_card[0].point==7 or d_card[0].point==9 or d_card[0].point==10):
                p_sts= hit(p_sts,p_card,desk,bet)
            elif p_sts['card_point'] ==13:
                p_sts['Stand'] ='Y'
                break
            elif p_sts['card_point'] ==12 and (d_card[0].point==4 or d_card[0].point==5 or d_card[0].point==6):
                p_sts['Stand'] ='Y'
                break
            elif p_sts['card_point'] ==12:
                p_sts= hit(p_sts,p_card,desk,bet)
            elif (p_sts['card_point'] ==10 or p_sts['card_point'] ==11) and(d_card[0].point==1 or d_card[0].point==10):
                p_sts= hit(p_sts,p_card,desk,bet)
            elif (p_sts['card_point'] ==10 or p_sts['card_point'] ==11):
                p_sts=Double(p_sts,p_card,desk,bet,'hit')
            elif p_sts['card_point'] ==9 and (d_card[0].point==3 or d_card[0].point==4 or d_card[0].point==5 or d_card[0].point==6):
                p_sts=Double(p_sts,p_card,desk,bet,'hit')
            elif p_sts['card_point'] ==9:
                p_sts= hit(p_sts,p_card,desk,bet)
            elif (p_sts['card_point'] ==4 or p_sts['card_point'] ==6) and (d_card[0].point==8 or d_card[0].point==9 or d_card[0].point==10 or d_card[0].point==1):
                p_sts= hit(p_sts,p_card,desk,bet)
            elif p_sts['card_point'] ==8 and(d_card[0].point==3 or d_card[0].point==4 or d_card[0].point==2 or d_card[0].point==7 or d_card[0].point==1 or d_card[0].point==8 or d_card[0].point==9 or d_card[0].point==10):
                p_sts= hit(p_sts,p_card,desk,bet)
            elif p_sts['card_point'] ==5 or p_sts['card_point'] ==6 or p_sts['card_point'] ==7 or p_sts['card_point'] ==8:
                p_sts= hit(p_sts,p_card,desk,bet)
            else:

                print('Hard Play go wrong','p_sts = ',p_sts,'d_card=',d_card[0].point)
                for i in range(len(p_card)):
                    print(p_card[i].point)
                break
#     return hands,tempcard_slot,choose_slot,games_record

# %%
def bf_sts_cal_for_split(p_card,bet):
    '''
    用來計算一開始的兩張，總共會帶來的狀態，需要呼叫card_count，去算點數、大小牌、用掉的牌數、以及有沒有ACE等等
    這裡產出的狀態會放在dataframe裡面，計算包含了BJ、兩張A可拆、一般牌可拆、一般牌可加倍
    # !!!分牌後沒有BJ，此處也與原本的狀態計算不同
    paras:
        p_card 傳入要計算的牌組 type:List()，List裡面放card物件
        bet    起始的注碼       type:int  
    return
        p_sts  該牌組的狀態     type:dict() 
    history:2022/10/9 done
    '''
    if(isinstance(p_card, list) == False):
        return 0
    card_total,card_big,card_small,card_ACE,ACE_Point=card_count(p_card)
#     print(p_card)
    if (p_card[0].point+p_card[1].point==11) and (p_card[0].point or p_card[1].point==1):#只有兩張時加起來十一點且有一張為1，就是BJ
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':21,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'N','Split_count':1,'Split_ACE':'N'
                  ,'surrender':'N'}
        #return p_sts
    elif (p_card[0].point == p_card[1].point) and ((p_card[0].point or p_card[1].point)==1):#兩張A的拆牌
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':12,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'Y','Split_count':1,'Split_ACE':'Y'
                  ,'surrender':'N'}
        #return p_sts
    elif (p_card[0].point == p_card[1].point) and (p_card[1].point!=1):#兩張其他的拆牌
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':ACE_Point,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'Y','Split_count':1,'Split_ACE':'N'
                  ,'surrender':'N'}
        #return p_sts
    else:
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':ACE_Point,
                  'BJ':'N','Bust':'N','double_available':'Y','Stand':'N','Split_available':'N','Split_count':1,'Split_ACE':'N'
                  ,'surrender':'N'}
        #return p_sts

# %%
def bf_sts_cal_for_derive1(p_card,bet):
    '''
    用來計算一開始的兩張，總共會帶來的狀態，需要呼叫card_count，去算點數、大小牌、用掉的牌數、以及有沒有ACE等等
    這裡產出的狀態會放在dataframe裡面，計算包含了BJ、兩張A可拆、一般牌可拆、一般牌可加倍
    # !!!分牌後沒有BJ，此處也與原本的狀態計算不同
    paras:
        p_card 傳入要計算的牌組 type:List()，List裡面放card物件
        bet    起始的注碼       type:int  
    return
        p_sts  該牌組的狀態     type:dict() 
    history:2022/10/9 done
    '''
#     print(p_card)
    if(isinstance(p_card, list) == 0):
        return 0
    card_total,card_big,card_small,card_ACE,ACE_Point=card_count(p_card)
    if (p_card[0].point+p_card[1].point==11) and (p_card[0].point or p_card[1].point==1):#只有兩張時加起來十一點且有一張為1，就是BJ
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':21,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'N','Split_count':1,'Split_ACE':'N'
                  ,'surrender':'N'}
        return p_sts
    elif (p_card[0].point == p_card[1].point) and (p_card[0].point==1 or p_card[1].point==1):#兩張A的拆牌
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':12,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'N','Split_count':1,'Split_ACE':'Y'
                  ,'surrender':'N'}
        return p_sts
    elif (p_card[0].point == p_card[1].point) and (p_card[1].point!=1):#兩張其他的拆牌
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':ACE_Point,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'Y','Split_count':1,'Split_ACE':'N'
                  ,'surrender':'N'}
        return p_sts
    else:
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':ACE_Point,
                  'BJ':'N','Bust':'N','double_available':'Y','Stand':'N','Split_available':'N','Split_count':1,'Split_ACE':'N'
                  ,'surrender':'N'}
        return p_sts

# %%
def bf_sts_cal_for_derive2(p_card,bet):
    '''
    用來計算一開始的兩張，總共會帶來的狀態，需要呼叫card_count，去算點數、大小牌、用掉的牌數、以及有沒有ACE等等
    這裡產出的狀態會放在dataframe裡面，計算包含了BJ、兩張A可拆、一般牌可拆、一般牌可加倍
    # !!!分牌後沒有BJ，此處也與原本的狀態計算不同
    paras:
        p_card 傳入要計算的牌組 type:List()，List裡面放card物件
        bet    起始的注碼       type:int  
    return
        p_sts  該牌組的狀態     type:dict() 
    history:2022/10/9 done
    '''
#     print(p_card)
    if(isinstance(p_card, list) == 0):
        return 0
    card_total,card_big,card_small,card_ACE,ACE_Point=card_count(p_card)

    if (p_card[0].point+p_card[1].point==11) and ((p_card[0].point or p_card[1].point)==1):#只有兩張時加起來十一點且有一張為1，就是BJ
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':2,'card_small':0,'card_total':2,'card_ACE':card_ACE,
               'card_point':21,'ACE_Point':21,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'N','Split_count':2,'Split_ACE':'N'
                  ,'surrender':'N'}
        return p_sts
    elif (p_card[0].point == p_card[1].point) and (p_card[0].point==1 or p_card[1].point==1):#兩張A的拆牌
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':2,'card_small':0,'card_total':2,'card_ACE':card_ACE,
               'card_point':2,'ACE_Point':12,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'N','Split_count':2,'Split_ACE':'Y'
                  ,'surrender':'N'}
        return p_sts
    elif (p_card[0].point == p_card[1].point) and (p_card[1].point!=1):#兩張其他的拆牌
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':ACE_Point,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'N','Split_count':2,'Split_ACE':'N'
                  ,'surrender':'N'}
        return p_sts
    else:
        p_sts={'weight':p_card[0].weighted+p_card[1].weighted,'bet':bet,'card_big':card_big,'card_small':card_small,
                'card_total':card_total,'card_ACE':card_ACE,'card_point':p_card[1].point+p_card[0].point,'ACE_Point':ACE_Point,
                  'BJ':'N','Bust':'N','double_available':'Y','Stand':'N','Split_available':'N','Split_count':2,'Split_ACE':'N'
                  ,'surrender':'N'}
        return p_sts

# %%
def split(p_sts,p_card,dealer,desk,bet):
    ''' ###split，若依照打法需要分牌，就走分牌，因為要看表，所以不能跟分牌判斷寫在一起。
    Paras:
        p_sts   當下處理牌組的狀況 type:dict
        p_card  玩家手牌     type:list
    Returns:
        None
    '''
    
    if(isinstance(p_card, list) == False):
        return 0
    

    if p_sts['Split_available'] == 'Y' and p_sts['card_ACE']>0 and p_sts['Split_count'] < 1: #AA對拆完補牌後就結束
        if dealer[0].point>=2:
            new1 = desk.pop()
            new2 = desk.pop()
            card_split_org = p_card.pop()
            p_card.append(new1)


            bf_sts_cal_for_split(p_card,bet)

            p_sts['Split_count']+=1

            if(p_sts['Split_count']>=2):
                p_sts['Split_available'] = 'N'

            return [new2,card_split_org]
        else:
            p_sts['Split_available'] = 'N' #不在這邊處理hit，先讓他離開
            return 0
    
    elif p_sts['Split_available'] == 'Y' and p_sts['Split_count'] < 2 : 
        if (p_card[0].point==10) or (p_card[0].point==9 and (dealer[0].point==7 or dealer[0].point==10 or dealer[0].point==1)):
            p_sts['Split_available']= 'N' 
            p_sts['Stand']='Y'
            return 0
        elif ((p_card[0].point==8) or (p_card[0].point==7)) and dealer[0].point==10:
            p_sts['surrender'] = 'Y'
            return 0
        elif (p_card[0].point==9 or(p_card[0].point==8 and dealer[0].point>=2) or
        (p_card[0].point==7 and dealer[0].point>=2 and dealer[0].point<=7) or
        (p_card[0].point==6 and dealer[0].point>=2 and dealer[0].point<=6) or 
        (p_card[0].point==4 and dealer[0].point>=5 and dealer[0].point<=6) or 
        (p_card[0].point==3 and dealer[0].point>=2 and dealer[0].point<=7)or
        (p_card[0].point==2 and dealer[0].point>=2 and dealer[0].point<=7)) :
            #把Pair區域裡面的P都塞進來了。
            new1 = desk.pop()
            new2 = desk.pop()
            card_split_org = p_card.pop()
            p_card.append(new1)
            bf_sts_cal_for_split(p_card,bet)

            p_sts['Split_count']+=1

            if(p_sts['Split_count']>=2):
                p_sts['Split_available'] = 'N'
            return [new2,card_split_org]
    else:
        return 0

# %% [markdown]
# # 以上暫時完成

# %%
def hit(p_sts,p_card,desk,bet):
    new_card=desk.pop() 
    p_card.append(new_card)
    p_sts=hit_sts_cal(p_sts,p_card,bet)
    return p_sts

# %%
def hit_card_count(p_card):
    '''
    被呼叫來算點數、大小牌、用掉的牌數、以及有沒有ACE等等
    這裡產出的狀態會放在dataframe裡面，計算包含了BJ、兩張A可拆、一般牌可拆、一般牌可加倍
    paras:
        p_card 傳入要計算的牌組 type:List()，List裡面放card物件
    return
        card_total 總共的牌數 其實都是2
        card_big   總共的大牌
        card_small 總共的小牌
        card_ACE   總共的ACE數
        ACE_Point  依照有沒有ACE動態判斷點數。
    history:2022/10/9 done
    '''
    card_ACE= 0
    card_big=0
    card_small=0
    total_weight=0
    card_point=0
    for i in range(len(p_card)) :
        if p_card[i].point==1:
            card_ACE+=1
    if card_ACE>0:
        for i in range(len(p_card)) :
            card_point+=p_card[i].point
        ACE_Point=card_point+10
    else:
        for i in range(len(p_card)) :
            card_point+=p_card[i].point
        ACE_Point=card_point
    for i in range(len(p_card)) :
        if p_card[i].weighted ==1:
            card_big += 0
            card_small += 1
        elif p_card[i].weighted ==-1:
            card_big += 1
            card_small += 0
        else :
            card_big += 0
            card_small += 0    
        total_weight+=p_card[i].weighted
    card_total=len(p_card)
    
    return card_total,card_big,card_small,card_ACE,ACE_Point,card_point,total_weight

# %%
def hit_sts_cal(p_sts,p_card,bet):
    '''
    用來計算加牌後的計算，總共會帶來的狀態，需要呼叫card_count，去算點數、大小牌、用掉的牌數、以及有沒有ACE等等
    這裡產出的狀態會放在dataframe裡面，計算包含了BJ、兩張A可拆、一般牌可拆、一般牌可加倍
    # !!!分牌後沒有BJ，此處也與原本的狀態計算不同
    paras:
        p_card 傳入要計算的牌組 type:List()，List裡面放card物件
        bet    起始的注碼       type:int  
    return
        p_sts  該牌組的狀態     type:dict() 
    history:2022/10/9 done
    '''
    card_total,card_big,card_small,card_ACE,ACE_Point,card_point,total_weight=hit_card_count(p_card)
    
    if card_point>21:
        p_sts={'weight':total_weight,'bet':bet,'card_big':card_big,'card_small':card_small,'card_total':card_total,
               'card_ACE':card_ACE,'card_point':card_point,'ACE_Point':ACE_Point,
                  'BJ':'N','Bust':'Y','double_available':'N','Stand':'N','Split_available':'N','Split_count':p_sts['Split_count'],'Split_ACE':p_sts['Split_ACE']
                  ,'surrender':'N'}
    elif card_point<=21 and ACE_Point>21:
        p_sts={'weight':total_weight,'bet':bet,'card_big':card_big,'card_small':card_small,'card_total':card_total,
               'card_ACE':card_ACE,'card_point':card_point,'ACE_Point':ACE_Point,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'N','Split_count':p_sts['Split_count'],'Split_ACE':p_sts['Split_ACE']
                  ,'surrender':'N'}
    else:#ACE_Point=card_point
        p_sts={'weight':total_weight,'bet':bet,'card_big':card_big,'card_small':card_small,'card_total':card_total,
               'card_ACE':card_ACE,'card_point':card_point,'ACE_Point':card_point,
                  'BJ':'N','Bust':'N','double_available':'N','Stand':'N','Split_available':'N','Split_count':p_sts['Split_count'],'Split_ACE':p_sts['Split_ACE']
                  ,'surrender':'N'}
    return p_sts

# %% [markdown]
# ### Bust先留著

# %%
def Bust(p_sts,p_card):
    ''' ###Bust，計算是否爆牌，若爆牌就結束了。
    Paras:
        p_sts   當下處理牌組的狀況 type:dict
        p_card  玩家手牌     type:list
    Returns:
        None
    '''
    if  p_sts['card_point']>21:
        p_sts['Bust'] = 'Y'
    else:
        p_sts['Bust'] = 'N'

# %% [markdown]
# ### surrender，先改成這樣晚點再接上

# %%
def surrender(p_sts,p_card,desk,bet):
    if len(p_card)==2:
        p_sts['surrender']= 'Y'
        return p_sts
    else:
        new_sts= hit(p_sts,p_card,desk,bet)
        return new_sts

# %% [markdown]
# ### Double，先改成這樣晚點再接上

# %%
def Double(p_sts,p_card,desk,bet,way):
    if p_sts['double_available']=='Y' :
        p_sts['bet']=p_sts['bet']*2
        new_sts=hit(p_sts,p_card,desk,bet)
        return new_sts
    elif way=='Stand':
        p_sts['Stand'] ='Y'
        p_sts['double_available']='N'
        return p_sts
    elif way == 'hit':
        new_sts=hit(p_sts,p_card,desk,bet)
        return new_sts

# %%
def dealer_play(p_card,desk):

    tempcard=desk.pop() 
    p_card.append(tempcard)
    p_sts =bf_sts_cal_for_dealer(p_card)
    p_sts['card_point']=0
    p_sts['ACE_Point']=0
    if p_sts['BJ']=='Y':
        return p_sts
    elif p_sts['card_ACE']>=1:
        for i in range(len(p_card)):
            p_sts['card_point']+=p_card[i].point
        p_sts['ACE_Point']=p_sts['card_point']+10
    else:
        for i in range(len(p_card)):
            p_sts['ACE_Point']+=p_card[i].point
            p_sts['card_point']+=p_card[i].point
    while (p_sts['card_point']<17 and p_sts['card_ACE']==0) or (p_sts['ACE_Point']<17 and p_sts['card_ACE']>0):
        p_sts= hit(p_sts,p_card,desk,0)
    
    return p_sts

# %%
def result_cal(p_sts,d_sts,row):
    if(isinstance(p_sts, dict) == False):
        return 0
    revenue = 0
    rate = 0
    if p_sts['BJ']=='Y':
        if d_sts['BJ']=='Y':
            result = 'P'
            rate=0
        else:
            result ='W'
            rate=1.5
    elif p_sts['surrender'] =='Y':
        result = 'S'
        rate =0.5
    elif p_sts['Bust']=='Y':
        result = 'L'
        rate = -1
    elif p_sts['Stand']=='Y':
        if d_sts['BJ'] == 'Y':
            result = 'L'
            rate = -1
        elif d_sts['Bust']=='Y':
            result ='W'
            rate=1
    elif p_sts['card_ACE']>0:
        if d_sts['card_ACE']>0:
            if p_sts['ACE_Point']>d_sts['ACE_Point']:
                result ='W'
                rate=1
            elif p_sts['ACE_Point']==d_sts['ACE_Point']:
                result = 'P'
                rate=0
            else:
                result = 'L'
                rate = -1
        else:
            if p_sts['ACE_Point']>d_sts['card_point']:
                result ='W'
                rate=1
            elif p_sts['ACE_Point']==d_sts['card_point']:
                result = 'P'
                rate=0
            else:
                result = 'L'
                rate = -1
    else:
        if d_sts['card_ACE']>0:
            if p_sts['card_point']>d_sts['ACE_Point']:
                result ='W'
                rate=1
            elif p_sts['card_point']==d_sts['ACE_Point']:
                result = 'P'
                rate=0
            else:
                result = 'L'
                rate = -1
        else:
            if p_sts['card_point']>d_sts['card_point']:
                result ='W'
                rate=1
            elif p_sts['card_point']==d_sts['card_point']:
                result = 'P'
                rate=0
            else:
                result = 'L'
                rate = -1
    revenue +=row['first_bet']*rate
  # print('t_weight=',t_weight,'and plus weight',p_sts['weight'],'=',t_weight+p_sts['weight'])
    
    return revenue

# %%
def true_num_cal(weight):
    if int(weight/6)>=6:
        true_num =6
    elif int(weight/6)==5:
        true_num =5
    elif int(weight/6)==4:
        true_num =4
    elif int(weight/6)==3:
        true_num =3
    elif int(weight/6)==2:
        true_num =2
    elif int(weight/6)==1:
        true_num =1
    else:
        true_num =0
    return true_num

# %%
def srate_cal(row):
    s_total=row['p1_sts']['card_small']+row['p2_sts']['card_small']+row['p3_sts']['card_small']
    card_total=row['p1_sts']['card_total']+row['p2_sts']['card_total']+row['p3_sts']['card_total']
    if row['p1_1_sts']!=0:
        s_total+=row['p1_1_sts']['card_small']
        card_total+=row['p1_1_sts']['card_total']
    else:
        s_total+=0
    if row['p1_2_sts']!=0:
        s_total+=row['p1_2_sts']['card_small']
        card_total+=row['p1_2_sts']['card_total']
    else:
        s_total+=0
    if row['p2_1_sts']!=0:
        s_total+=row['p2_1_sts']['card_small']
        card_total+=row['p2_1_sts']['card_total']
    else:
        s_total+=0
    if row['p2_2_sts']!=0:
        s_total+=row['p2_2_sts']['card_small']
        card_total+=row['p2_2_sts']['card_total']
    else:
        s_total+=0
    if row['p3_1_sts']!=0:
        s_total+=row['p3_1_sts']['card_small']
        card_total+=row['p3_1_sts']['card_total']
    else:
        s_total+=0
    if row['p3_2_sts']!=0:
        s_total+=row['p3_2_sts']['card_small']
        card_total+=row['p3_2_sts']['card_total']
    else:
        s_total+=0
    return s_total/card_total

# %%
def brate_cal(row):
    b_total=row['p1_sts']['card_big']+row['p2_sts']['card_big']+row['p3_sts']['card_big']
    card_total=row['p1_sts']['card_total']+row['p2_sts']['card_total']+row['p3_sts']['card_total']
    if row['p1_1_sts']!=0:
        b_total+=row['p1_1_sts']['card_big']
        card_total+=row['p1_1_sts']['card_total']
    else:
        b_total+=0
    if row['p1_2_sts']!=0:
        b_total+=row['p1_2_sts']['card_big']
        card_total+=row['p1_2_sts']['card_total']
    else:
        b_total+=0
    if row['p2_1_sts']!=0:
        b_total+=row['p2_1_sts']['card_big']
        card_total+=row['p2_1_sts']['card_total']
    else:
        b_total+=0
    if row['p2_2_sts']!=0:
        b_total+=row['p2_2_sts']['card_big']
        card_total+=row['p2_2_sts']['card_total']
    else:
        b_total+=0
    if row['p3_1_sts']!=0:
        b_total+=row['p3_1_sts']['card_big']
        card_total+=row['p3_1_sts']['card_total']
    else:
        b_total+=0
    if row['p3_2_sts']!=0:
        b_total+=row['p3_2_sts']['card_big']
        card_total+=row['p3_2_sts']['card_total']
    else:
        b_total+=0
    return b_total/card_total

# %%
isinstance(simulation['p1_1_sts'], list) == False
# Out:
# True

# %%
#計算每300筆的震盪,還需要確認筆數
simulation['running_revenue'] = simulation['total_revenue'] = simulation['total_revenue'].cumsum()

tmp  = []
for i in range(0,int(len(simulation)/300)):
    tmp.append(simulation['running_revenue'].iloc[i*300])
    
wave = {'300':tmp}
wave = pd.DataFrame(wave)

wave['diff'] = wave['300'].diff()

# %%
wave
# Out:
#         300    diff
# 0       0.0     NaN
# 1    -272.5  -272.5
# 2    -364.0   -91.5
# 3    -409.5   -45.5
# 4    -493.0   -83.5
# 5    -581.0   -88.0
# 6    -719.5  -138.5
# 7    -820.0  -100.5
# 8    -915.0   -95.0
# 9   -1092.0  -177.0
# 10  -1443.5  -351.5
# 11  -2464.0 -1020.5
# 12  -2643.5  -179.5
# 13  -2801.5  -158.0
# 14  -2999.5  -198.0
# 15  -3096.5   -97.0
# 16  -3641.5  -545.0
# 17  -6229.0 -2587.5
# 18  -7430.0 -1201.0
# 19  -9455.0 -2025.0
# 20 -13235.0 -3780.0
# 21 -17825.0 -4590.0
# 22 -21200.0 -3375.0
# 23 -23495.0 -2295.0
# 24 -26165.0 -2670.0
# 25 -28535.0 -2370.0
# 26 -30335.0 -1800.0
# 27 -32045.0 -1710.0
# 28 -34310.0 -2265.0
# 29 -36185.0 -1875.0
# 30 -36288.5  -103.5
# 31 -36382.5   -94.0
# 32 -36499.5  -117.0

# %%
#主程式
Full_desk = desk1 + desk2 + desk3 + desk4 + desk5 + desk6 

t1 = datetime.now()
seed = list(range(0,10000))
np.random.shuffle(seed)
true_num=0
weight=0
simulation = pd.DataFrame(seed)

# create slot for each full desk and then drop full desk

simulation['card_slot'] = simulation[0].apply(lambda row:shuffle(Full_desk,row))

simulation = simulation.rename(columns = {0:'seed'})

simulation['p1'] = simulation['card_slot'].apply(lambda row:distribution(row,0,1))
# pop_card('card_slot',2)
simulation['p2'] = simulation['card_slot'].apply(lambda row:distribution(row,2,3))
# pop_card('card_slot',2)
simulation['p3'] = simulation['card_slot'].apply(lambda row:distribution(row,4,5))
# pop_card('card_slot',2)
simulation['dealer'] = simulation['card_slot'].apply(lambda row:[row[6]])
# pop_card('card_slot',1)

game_start(true_num,weight)

#所有P1分牌,bf_sts_cal_for_derive有分1跟2，主要是在更新split_count有差，也順便調整了計算點數跟大小牌
simulation['p1_1'] = simulation.apply(lambda row:split(row['p1_sts'],row['p1'],row['dealer'],row['card_slot'],1),axis=1)
simulation['p1_1_sts']=simulation.apply(lambda row:bf_sts_cal_for_derive1(row['p1_1'],1),axis=1)
# simulation['p1_1_1'] = simulation.apply(lambda row:split(row['p1_1_sts'],row['p1_1'],row['dealer'],row['card_slot'],1),axis=1)
# simulation['p1_1_1_sts']=simulation.apply(lambda row:bf_sts_cal_for_derive2(row['p1_1_1'],1),axis=1)#這裡分完後，p_1的split_count其實還是只有1，但是因為我不會再丟進來了，所以就沒有差吧？
simulation['p1_2'] = simulation.apply(lambda row:split(row['p1_sts'],row['p1'],row['dealer'],row['card_slot'],1),axis=1)
simulation['p1_2_sts']=simulation.apply(lambda row:bf_sts_cal_for_derive2(row['p1_2'],1),axis=1)

#所有P2分牌,bf_sts_cal_for_derive有分1跟2，主要是在更新split_count有差，也順便調整了計算點數跟大小牌
simulation['p2_1'] = simulation.apply(lambda row:split(row['p2_sts'],row['p2'],row['dealer'],row['card_slot'],1),axis=1)
simulation['p2_1_sts']=simulation.apply(lambda row:bf_sts_cal_for_derive1(row['p2_1'],1),axis=1)
# simulation['p2_1_1'] = simulation.apply(lambda row:split(row['p2_1_sts'],row['p2_1'],row['dealer'],row['card_slot'],1),axis=1)
# simulation['p2_1_1_sts']=simulation.apply(lambda row:bf_sts_cal_for_derive2(row['p2_1_1'],1),axis=1)#這裡分完後，p_1的split_count其實還是只有1，但是因為我不會再丟進來了，所以就沒有差吧？
simulation['p2_2'] = simulation.apply(lambda row:split(row['p2_sts'],row['p2'],row['dealer'],row['card_slot'],1),axis=1)
simulation['p2_2_sts']=simulation.apply(lambda row:bf_sts_cal_for_derive2(row['p2_2'],1),axis=1)

#所有P1分牌,bf_sts_cal_for_derive有分1跟2，主要是在更新split_count有差，也順便調整了計算點數跟大小牌
simulation['p3_1'] = simulation.apply(lambda row:split(row['p3_sts'],row['p3'],row['dealer'],row['card_slot'],1),axis=1)
simulation['p3_1_sts']=simulation.apply(lambda row:bf_sts_cal_for_derive1(row['p3_1'],1),axis=1)
# simulation['p3_1_1'] = simulation.apply(lambda row:split(row['p3_1_sts'],row['p3_1'],row['dealer'],row['card_slot'],1),axis=1)
# simulation['p3_1_1_sts']=simulation.apply(lambda row:bf_sts_cal_for_derive2(row['p3_1_1'],1),axis=1)#這裡分完後，p_1的split_count其實還是只有1，但是因為我不會再丟進來了，所以就沒有差吧？
simulation['p3_2'] = simulation.apply(lambda row:split(row['p3_sts'],row['p3'],row['dealer'],row['card_slot'],1),axis=1)
simulation['p3_2_sts']=simulation.apply(lambda row:bf_sts_cal_for_derive2(row['p3_2'],1),axis=1)

#開始play card  play_card(p_sts,p_card,d_card,desk,bet):
simulation.apply(lambda row:play_card(row['p1_sts'],row['p1'],row['dealer'],row['card_slot'],1),axis=1)
simulation.apply(lambda row:play_card(row['p2_sts'],row['p2'],row['dealer'],row['card_slot'],1),axis=1)
simulation.apply(lambda row:play_card(row['p3_sts'],row['p3'],row['dealer'],row['card_slot'],1),axis=1)


simulation['t_weight']=simulation.apply(lambda row:t_weight_cal(row),axis=1)
simulation['acc_weight']=simulation['t_weight'].cumsum()
simulation['t_weight_adjust']=simulation.apply(lambda row:t_weight_adjust(row['acc_weight']),axis=1)

simulation['true_num']=simulation.apply(lambda row:true_num_cal(row['t_weight_adjust']),axis=1)
simulation['first_bet']=simulation.apply(lambda row:first_bet(row['true_num']),axis=1)


# dealer_play(p_card,desk)
simulation['d_sts']= simulation.apply(lambda row:dealer_play(row['dealer'],row['card_slot']),axis=1)
#result_cal(p_sts,d_sts)
simulation['p1_revenue']=simulation.apply(lambda row:result_cal(row['p1_sts'],row['d_sts'],row),axis=1)
simulation['p1_1_revenue']=simulation.apply(lambda row:result_cal(row['p1_1_sts'],row['d_sts'],row),axis=1)
simulation['p1_2_revenue']=simulation.apply(lambda row:result_cal(row['p1_2_sts'],row['d_sts'],row),axis=1)
# simulation['p3_revenue']=simulation.apply(lambda row:result_cal(row['p3_sts'],row['d_sts']),axis=1)

simulation['p2_revenue']=simulation.apply(lambda row:result_cal(row['p2_sts'],row['d_sts'],row),axis=1)
simulation['p2_1_revenue']=simulation.apply(lambda row:result_cal(row['p2_1_sts'],row['d_sts'],row),axis=1)
simulation['p2_2_revenue']=simulation.apply(lambda row:result_cal(row['p2_2_sts'],row['d_sts'],row),axis=1)
# simulation['p3_revenue']=simulation.apply(lambda row:result_cal(row['p3_sts'],row['d_sts']),axis=1)




simulation['p3_revenue']=simulation.apply(lambda row:result_cal(row['p3_sts'],row['d_sts'],row),axis=1)
simulation['p3_1_revenue']=simulation.apply(lambda row:result_cal(row['p3_1_sts'],row['d_sts'],row),axis=1)
simulation['p3_2_revenue']=simulation.apply(lambda row:result_cal(row['p3_2_sts'],row['d_sts'],row),axis=1)
# simulation['p3_revenue']=simulation.apply(lambda row:result_cal(row['p3_sts'],row['d_sts']),axis=1)

simulation['total_revenue']=simulation.apply(lambda row:revenue_cal(row),axis=1)

simulation['s_rate']=simulation.apply(lambda row:srate_cal(row),axis=1)
simulation['b_rate']=simulation.apply(lambda row:brate_cal(row),axis=1)

simulation['p1_detail'] = simulation['p1'].apply(lambda row:print_detail(row))
simulation['p2_detail'] = simulation['p2'].apply(lambda row:print_detail(row))
simulation['p3_detail'] = simulation['p3'].apply(lambda row:print_detail(row))
simulation['p1_1_detail'] = simulation['p1_1'].apply(lambda row:print_detail(row))
simulation['p1_2_detail'] = simulation['p1_1'].apply(lambda row:print_detail(row))
simulation['p2_1_detail'] = simulation['p1_1'].apply(lambda row:print_detail(row))
simulation['p2_2_detail'] = simulation['p1_1'].apply(lambda row:print_detail(row))
simulation['p3_1_detail'] = simulation['p1_1'].apply(lambda row:print_detail(row))
simulation['p3_2_detail'] = simulation['p1_1'].apply(lambda row:print_detail(row))
simulation['dealer_detail'] = simulation['dealer'].apply(lambda row:print_detail(row))

t2 = datetime.now()
print('done')
# Out:
# Hard Play go wrong p_sts =  {'weight': 2, 'bet': 1, 'card_big': 0, 'card_small': 2, 'card_total': 2, 'card_ACE': 0, 'card_point': 4, 'ACE_Point': 4, 'BJ': 'N', 'Bust': 'N', 'double_available': 'N', 'Stand': 'N', 'Split_available': 'N', 'Split_count': 2, 'Split_ACE': 'N', 'surrender': 'N'} d_card= 5
# 2
# 2
# done

# %%
def print_detail(card):
    if(isinstance(card, list)):
        res = []
        for i in range(0,len(card)):
            tmp_name = str(card[i].name)
            tmp_color = card[i].color
            res.append(tmp_name+'_'+tmp_color)
        return res
    else:
        return 0

# %%
simulation.to_excel('simulation.xlsx',index = False)

# %%
#延續分析使用。
simulation['total_revenue'].std()
simulation['total_revenue'].mean()
